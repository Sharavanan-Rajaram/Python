# %% [markdown]
# # <center>PGP Data Science Engineering</center>
# ## <center>Introduction to Programming – Mini Project:</center>

# %% [markdown]
# ### Problem 1:
#
# 1. Write a program to calculate area of shapes. Your program should be capable of calculating the area of a square, rectangle, triangle and a circle. The user should be presented with options to select the shape. Based on which shape is chosed by the user, the program should ask for the appropriate input and print the resulting area on the screen.
#
# When the program is run, the screen should display something like this:
#
# **Which shape would you like to calculate the area for? Please enter the option number-**<br>
# **1. Square**<br>
# **2. Rectangle**<br>
# **3. Triangle**<br>
# **4. Circle**<br>
# **Enter Option: _**
#
# Say the user enters the option 1.
#
# **Please enter the length of a side: _**
#
# If the user enters a value of 5. The output should be:
#
# **The area of the square is 25**
#
# This program should indicate that the input is invalid if the user enters a character instead of a number as input. For instance if the user enters a value of ‘a’ instead of 5 in the previous example the program should prompt:
#
# **Invalid input, please enter a number: _**

# %%
#used try except block and while True(infinite loop) to get the correct input until the user enters it correctly and then
#it goes to the else part and see the break statement and breaks out of the infinite while loop

print(''' Which shape would you like to calculate the area for? Please enter the option number-
1. Square
2. Rectangle
3. Triangle
4. Circle''')

while True:
    try:
        uInput= int(input('Enter one Option:'))
    except ValueError:
        print("Enter a valid input from 1-4 ")         
    else:
        break
        

if(uInput==1):
    
    while True:
        try:
            sqrInput=float(input('Enter the length of the side: '))
        except ValueError:
            print("Enter a valid input like in numbers and not characters")         
        else:
            break
            
    areaSquare= sqrInput*sqrInput
    print('The are of the square is ',areaSquare)
       
elif(uInput==2):
    while True:
        try:
            rectInput_length=float(input('Enter the length of the side: '))
            rectInput_breath=float(input('Enter the breath of the side: '))
        except ValueError:
            print("Enter a valid input like in numbers and not characters")
        else:
            break
    

    areaRectangle = rectInput_length*rectInput_breath
    print('The are of the Rectangle is ',areaRectangle)
        
elif(uInput==3):
    while True:
        try:
            triInput_base=float(input('Enter the length of the side: '))
            triInput_height=float(input('Enter the breath of the side: '))
        except ValueError:
            print("Enter a valid input like in numbers and not characters")
        else:
            break
            
    areaTriangle = (triInput_base*triInput_height)/2
    print('The are of the Triangle is ',areaTriangle)
     
elif(uInput==4):
    while True:
        try:
            circleInput_radius=float(input('Enter the radius of the circle: '))
        except ValueError:
            print("Enter a valid input like in numbers and not characters")
        else:
            break
            
    areaCircle = 3.14*(circleInput_radius**2)
    print('The are of the circle is ',areaCircle)
    
else:
    print('Invalid input from the given options 1-4 ')
# Out:
#  Which shape would you like to calculate the area for? Please enter the option number-
# 1. Square
# 2. Rectangle
# 3. Triangle
# 4. Circle
# Enter one Option:a
# Enter a valid input from 1-4
# Enter one Option:a
# Enter a valid input from 1-4
# Enter one Option:!
# Enter a valid input from 1-4
# Enter one Option:4
# Enter the radius of the circle: 2
# The are of the circle is  12.56

# %% [markdown]
# ### Problem 2:
#
# Create and encrypter in python based on the ceaser cipher. It is a substitution cipher where each character of the original text is shifted a certain number characters in the alphabet. Write a function that would require 2 arguments – the input text to be encrypted and a key. For eg: Given the input text ‘hello’ and the key 3, the resulting encryted text would be ‘khoor’. Here you can see that every character in the string hello is shifted by 3 characters. ‘h’ has shifted to ‘k’, ‘e’ has shifted to ‘h’ and so on. If a key of 5 were used, the resulting string would be ‘mjqqt’. This function should be capable of ignoring any characters which are not alphabets. Th2 character ‘z’ entered b
# y the user for a key of 3 would result in ‘c’.
#
# Usage:<br>
# **encrypt(‘hello world!’, 3)**<br>
# **‘khoor zruog!’**
#
# Similarly create decrypter which can decode the encryted text when provided the input text and key
#
# Usage:<br>
# **decrypt(‘khoor zruog!’, 3)**<br>
# **‘hello world!’**
#
# For the sake of simplicity you can assume that input solely consists of lowercase alphabets, spaces and punctuation symbols. Numbers in the input text would also be ignored similar to symbols.

# %%
# chr(ord(char) + shift) Tried it works fine for 3 but 4 is given it shows op as 'lipps {svph!'   { isntead of a
# chr((ord(char) + shift)%26) it was showing the op like  !(square boxes and !) 
# so searched for it and found 97 is start ascii val of 'a' so used this chr((ord(a) + key - 97) % 26 + 97)
#If the input text if full of Capital letters then i would have used chr((ord(a) + key - 65) % 26 + 65) 

def ciphering(text,key):
    cipher = ""
    for a in text:
        if a.isalpha() : 
            cipher = cipher + chr((ord(a) + key - 97) % 26 + 97) 
        else: 
            cipher += a #used when the space is read or special char like exclamatory
    return cipher

def deciphering(cypher,key):
    decipher = ""
    for b in cypher:
        if b.isalpha() : 
            decipher = decipher + chr((ord(b) - key - 97) % 26 + 97) #same as above but sub the key val as its decypering
        else: 
            decipher += b  #used when the space is read or special char like exclamatory
    return decipher

cipher_key = 3
cipher_text = "hello world!"
print('Test String:',cipher_text)

cipher= ciphering(cipher_text,cipher_key)
print('Ciphered Value:',cipher)

decipher = deciphering(cipher,cipher_key)
print('DeCiphered Value:',decipher)
# Out:
# Test String: hello world!
# Ciphered Value: khoor zruog!
# DeCiphered Value: hello world!
