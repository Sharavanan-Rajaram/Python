# %% [markdown]
# Purely based on threshold conditions at the time of writing this code.
#
# V = 37.3 + 1.8 * True = 37.3 + 1.8 * 6 = 47.9%

# %%
presidentApproval=0
presidentRejection=0

reasonsList=['Republicans lost the U.S. House midterms in 2018.',
             'No Republicans challenged Trump.',
             'Doesn’t look like he’s stepping down.',
             'Despite claims by Kanye West to be running, this is a two-party race.',
             'The coronavirus pandemic has pushed the economy into recession.',
             'The pandemic has caused such negative GDP growth in 2020',
             'Through his tax cut, but mostly through his executive orders, Trump has fundamentally changed the policies of the Obama era.',
             'There has been considerable social unrest on the streets, with enough violence to threaten the social order.',
             'As I predicted, Trump was impeached. Plus, he has plenty of other scandals.',
             'We’ve had some very difficult moments with Donald Trump',
             'While Trump hasn’t had any big, splashy failures, he hasn’t had any major successes either.',
             'Trump is a great showman, but he only appeals to a narrow slice of Americans',
             'Biden is a decent, empathetic person, but he’s not inspirational or charismatic.']

dict1={'Party Mandate':'After the midterm elections, the incumbent party holds more seats inthe U.S. House of Representatives than it did after the previousmidterm elections.',
      'Contest':'There is no serious contest for the incumbent-party nomination.',
      'Incumbency':'The incumbent-party candidate is the sitting president.',
      'Third party':'There is no significant third party or independent campaign.',
      'Short-term economy':'The economy is not in recession during the election campaign.',
      'Long-term economy':'Real per-capita economic growth during the term equals or exceeds mean growth during the previous two terms.',
      'Policy change' : 'The incumbent administration effects major changes in national policy.',
      'Social unrest':'There is no sustained social unrest during the term.',
      'Scandal':'The incumbent administration is untainted by major scandal.',
      'Foreign/military failure':'The incumbent administration suffers no major failure in foreign or military affairs.',
      'Foreign/military success':'The incumbent administration achieves a major success in foreign or military affairs.',
      'Incumbent charisma':'The incumbent-party candidate is charismatic or a national hero.',
      'Challenger charisma':'The challenging-party candidate is not charismatic or a national hero.'}

val=0

for i,j in dict1.items():
    print(i,j)
    print('Based on Data the below reason is given below for',i)
    print(reasonsList[val])
    print() #for printing empty line
    uInput=input('''Enter one option from below
    1.True
    2.False
    ''')
    print()
    
    while(uInput !='1' and uInput!='2'):
            uInput=input('''Invalid input! Enter one option from below
    1.True
    2.False
    ''')
    print()        
    if(uInput=='1'):
        #print('The user accepts the reason given')
        presidentApproval+=1
        print('Predient approval for 13 keys to white house',presidentApproval)
        print() 
    elif(uInput=='2'):
        #print('The user accepts the reason given')
        presidentRejection+=1
        print('Predient Rejection for 13 keys to white house',presidentRejection)
        print() 
        
print('Final Presient Approval from 13 keys',presidentApproval)
print('Final President Rejection from 13 keys',presidentRejection)

V = 37.3 + 1.8 * presidentApproval
print('Final ratings for Incumbent President ',V)

if (V<49):
    print('President loses the election')
else:
    print('President can win the election')
# Out:
# Party Mandate After the midterm elections, the incumbent party holds more seats inthe U.S. House of Representatives than it did after the previousmidterm elections.
# Based on Data the below reason is given below for Party Mandate
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 1
#
# Contest There is no serious contest for the incumbent-party nomination.
# Based on Data the below reason is given below for Contest
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 2
#
# Incumbency The incumbent-party candidate is the sitting president.
# Based on Data the below reason is given below for Incumbency
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 3
#
# Third party There is no significant third party or independent campaign.
# Based on Data the below reason is given below for Third party
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 4
#
# Short-term economy The economy is not in recession during the election campaign.
# Based on Data the below reason is given below for Short-term economy
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 5
#
# Long-term economy Real per-capita economic growth during the term equals or exceeds mean growth during the previous two terms.
# Based on Data the below reason is given below for Long-term economy
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 6
#
# Policy change The incumbent administration effects major changes in national policy.
# Based on Data the below reason is given below for Policy change
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     1
#
#
# Predient approval for 13 keys to white house 7
#
# Social unrest There is no sustained social unrest during the term.
# Based on Data the below reason is given below for Social unrest
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 1
#
# Scandal The incumbent administration is untainted by major scandal.
# Based on Data the below reason is given below for Scandal
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 2
#
# Foreign/military failure The incumbent administration suffers no major failure in foreign or military affairs.
# Based on Data the below reason is given below for Foreign/military failure
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 3
#
# Foreign/military success The incumbent administration achieves a major success in foreign or military affairs.
# Based on Data the below reason is given below for Foreign/military success
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 4
#
# Incumbent charisma The incumbent-party candidate is charismatic or a national hero.
# Based on Data the below reason is given below for Incumbent charisma
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 5
#
# Challenger charisma The challenging-party candidate is not charismatic or a national hero.
# Based on Data the below reason is given below for Challenger charisma
# Republicans lost the U.S. House midterms in 2018.
#
# Enter one option from below
#     1.True
#     2.False
#     2
#
#
# Predient Rejection for 13 keys to white house 6
#
# Final Presient Approval from 13 keys 7
# Final President Rejection from 13 keys 6
# Final ratings for Incumbent President  49.9
# President can win the election

# %% [markdown]
# # 13 keys and the context

# %% [markdown]
# 1. Party Mandate: After the midterm elections, the incumbent party holds more seats in the House than it did after the previous midterm elections. False. “Republicans lost the U.S. House midterms in 2018.”
#
# 2. Contest: There is no serious contest for the incumbent-party nomination. True. “No Republicans challenged Trump.”
#
# 3. Incumbency: The sitting president is running for re-election. True. “Doesn’t look like he’s stepping down.”
#
# 4. Third Party: There is no major third-party challenge. True. “Despite claims by Kanye West to be running, this is a two-party race.”
#
# 5. Short-Term Economy: The economy during the election season is not in recession. False. “The [coronavirus] pandemic has pushed the economy into recession.”
#
# 6. Long-Term Economy: Real annual per-capita economic growth during the term equals or exceeds mean growth during the two previous terms. False. “The pandemic has caused such negative GDP growth in 2020 that the key has turned false.”
#
# 7. Policy Change: The incumbent causes major changes in national policy. True. ”Through his tax cut, but mostly through his executive orders, Trump has fundamentally changed the policies of the Obama era.”
#
# 8. Social Unrest: There is no sustained social unrest during the campaign. False. “There has been considerable social unrest on the streets, with enough violence to threaten the social order.”
#
# 9. Scandal: The incumbent administration is untainted by major scandals. False. “As I predicted, Trump was impeached. Plus, he has plenty of other scandals.”
#
# 10. Foreign or Military Failure: The incumbent administration suffers no major failure in foreign or military affairs. True. “We’ve had some very difficult moments with Donald Trump, but so far, true.”
#
# 11. Foreign or Military Success: The incumbent administration achieves a major success in foreign or military affairs. False. “While Trump hasn’t had any big, splashy failures, he hasn’t had any major successes either.”
#
# 12. Incumbent Charisma: The incumbent party candidate is charismatic. False. “Trump is a great showman, but he only appeals to a narrow slice of Americans.”
#
# 13. Challenger Charisma: The challenging party candidate is not charismatic. True. “Biden is a decent, empathetic person, but he’s not inspirational or charismatic.”
